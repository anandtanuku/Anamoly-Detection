# %%
import pandas as pd

# Load dataset
df = pd.read_csv("../data/raw/network.csv", low_memory=False)
print("Shape:", df.shape)
df.head()
# Out:
# Shape: (82332, 45)
#    id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 0   1  0.000011   udp       -   INT      2      0     496       0
# 1   2  0.000008   udp       -   INT      2      0    1762       0
# 2   3  0.000005   udp       -   INT      2      0    1068       0
# 3   4  0.000006   udp       -   INT      2      0     900       0
# 4   5  0.000010   udp       -   INT      2      0    2126       0
#
#           rate  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  \
# 0   90909.0902  ...                 1               2             0
# 1  125000.0003  ...                 1               2             0
# 2  200000.0051  ...                 1               3             0
# 3  166666.6608  ...                 1               3             0
# 4  100000.0025  ...                 1               3             0
#
#    ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  \
# ...

# %%
# Check what columns are available
df.columns.tolist()
# Out:
# ['id',
#  'dur',
#  'proto',
#  'service',
#  'state',
#  'spkts',
#  'dpkts',
#  'sbytes',
#  'dbytes',
#  'rate',
#  'sttl',
#  'dttl',
#  'sload',
#  'dload',
#  'sloss',
#  'dloss',
#  'sinpkt',
#  'dinpkt',
#  'sjit',
#  'djit',
#  'swin',
#  'stcpb',
#  'dtcpb',
#  'dwin',
#  'tcprtt',
#  'synack',
#  'ackdat',
#  'smean',
#  'dmean',
#  'trans_depth',
#  'response_body_len',
#  'ct_srv_src',
#  'ct_state_ttl',
#  'ct_dst_ltm',
#  'ct_src_dport_ltm',
#  'ct_dst_sport_ltm',
#  'ct_dst_src_ltm',
#  'is_ftp_login',
#  'ct_ftp_cmd',
#  'ct_flw_http_mthd',
#  'ct_src_ltm',
#  'ct_srv_dst',
#  'is_sm_ips_ports',
#  'attack_cat',
#  'label']

# %%
df["label"] = df["label"].astype(int)
print(df["label"].value_counts())

if "attack_cat" in df.columns:
    df["attack_cat"] = df["attack_cat"].astype(str).str.lower()
# Out:
# label
# 1    45332
# 0    37000
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(x=df["label"])
plt.title("Class Distribution (Normal vs Attack)")
plt.xlabel("Label (0 = Normal, 1 = Attack)")
plt.ylabel("Count")
plt.show()

# %%
corr = df.select_dtypes("number").corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr, cmap="coolwarm")
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
from pathlib import Path

processed_path = Path("../data/processed")
processed_path.mkdir(parents=True, exist_ok=True)

df.to_csv(processed_path / "clean_network.csv", index=False)
print("✅ Cleaned file saved at data/processed/clean_network.csv")
# Out:
# ✅ Cleaned file saved at data/processed/clean_network.csv
